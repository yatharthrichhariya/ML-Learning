# %%
import pandas as pd

# %%
df=pd.read_csv('weather_dataset_2025.csv')

# %%
df.head()
# Out:
#          Date    City  Temperature_C  Humidity_%  Wind_Speed_km_h  \
# 0  2025-01-01  Riyadh           15.8          94             21.0
# 1  2025-01-01  Jeddah           31.5          54             25.3
# 2  2025-01-01  Dammam           30.4          33              8.6
# 3  2025-01-01   Dubai           34.0          37             18.7
# 4  2025-01-01    Doha           28.3          32              6.8
#
#    Precipitation_mm      Condition
# 0              0.00         Cloudy
# 1              3.71          Windy
# 2              3.14  Partly Cloudy
# 3              0.00          Foggy
# 4              0.00          Rainy

# %% [markdown]
# **Opening a CSV File from an URL**

# %%
import requests
from io import StringIO

url='https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
headers={"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# **Sep Parameter**

# %%
titanic=pd.read_csv("titanic.tsv",sep='\t',names=["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"])

# %%
titanic.to_csv("Titanic.csv",index=False)

# %% [markdown]
# **Index_col parameter**

# %%
pd.read_csv('weather_dataset_2025.csv',index_col='Date')
# Out:
#                  City  Temperature_C  Humidity_%  Wind_Speed_km_h  \
# Date
# 2025-01-01     Riyadh           15.8          94             21.0
# 2025-01-01     Jeddah           31.5          54             25.3
# 2025-01-01     Dammam           30.4          33              8.6
# 2025-01-01      Dubai           34.0          37             18.7
# 2025-01-01       Doha           28.3          32              6.8
# ...               ...            ...         ...              ...
# 2025-12-31     Sydney           33.5          71             22.9
# 2025-12-31    Toronto            9.1          43             37.4
# 2025-12-31     Berlin            6.3          42             23.7
# 2025-12-31     Mumbai           27.6          58             12.5
# 2025-12-31  Singapore           44.3          75              4.6
#
#             Precipitation_mm      Condition
# Date
# 2025-01-01              0.00         Cloudy
# 2025-01-01              3.71          Windy
# ...

# %% [markdown]
# **Header parameter**

# %%
pd.read_csv('Train_Status.csv',header=1)
# Out:
#    0  0.1  0.2  0.3  1234  50     Rampur
# 0  1    1    1    1  5678  56  Sultanpur
# 1  2    2    2    2  5342  89    Vidisha
# 2  3    3    3    3  6678  70     Bhopal

# %% [markdown]
# **use_cols parameter**

# %%
pd.read_csv('weather_dataset_2025.csv',usecols=['Date','City','Temperature_C','Condition'])
# Out:
#             Date       City  Temperature_C      Condition
# 0     2025-01-01     Riyadh           15.8         Cloudy
# 1     2025-01-01     Jeddah           31.5          Windy
# 2     2025-01-01     Dammam           30.4  Partly Cloudy
# 3     2025-01-01      Dubai           34.0          Foggy
# 4     2025-01-01       Doha           28.3          Rainy
# ...          ...        ...            ...            ...
# 5470  2025-12-31     Sydney           33.5          Sunny
# 5471  2025-12-31    Toronto            9.1          Sunny
# 5472  2025-12-31     Berlin            6.3          Windy
# 5473  2025-12-31     Mumbai           27.6         Cloudy
# 5474  2025-12-31  Singapore           44.3         Stormy
#
# [5475 rows x 4 columns]

# %% [markdown]
# **Squeeze parameters**

# %%
pd.read_csv('weather_dataset_2025.csv',usecols=['City'])['City']
# Out:
# 0          Riyadh
# 1          Jeddah
# 2          Dammam
# 3           Dubai
# 4            Doha
#           ...
# 5470       Sydney
# 5471      Toronto
# 5472       Berlin
# 5473       Mumbai
# 5474    Singapore
# Name: City, Length: 5475, dtype: object

# %% [markdown]
# **Skiprows/nrows Parameter**

# %%
pd.read_csv("weather_dataset_2025.csv",skiprows=[0,10])
# Out:
#       2025-01-01     Riyadh  15.8  94  21.0    0.0         Cloudy
# 0     2025-01-01     Jeddah  31.5  54  25.3   3.71          Windy
# 1     2025-01-01     Dammam  30.4  33   8.6   3.14  Partly Cloudy
# 2     2025-01-01      Dubai  34.0  37  18.7   0.00          Foggy
# 3     2025-01-01       Doha  28.3  32   6.8   0.00          Rainy
# 4     2025-01-01      Cairo  12.8  60  17.8   9.14          Sunny
# ...          ...        ...   ...  ..   ...    ...            ...
# 5468  2025-12-31     Sydney  33.5  71  22.9   4.88          Sunny
# 5469  2025-12-31    Toronto   9.1  43  37.4   5.03          Sunny
# 5470  2025-12-31     Berlin   6.3  42  23.7  10.68          Windy
# 5471  2025-12-31     Mumbai  27.6  58  12.5   3.23         Cloudy
# 5472  2025-12-31  Singapore  44.3  75   4.6   0.00         Stormy
#
# [5473 rows x 7 columns]

# %%
pd.read_csv('weather_dataset_2025.csv',nrows=100)
# Out:
#           Date      City  Temperature_C  Humidity_%  Wind_Speed_km_h  \
# 0   2025-01-01    Riyadh           15.8          94             21.0
# 1   2025-01-01    Jeddah           31.5          54             25.3
# 2   2025-01-01    Dammam           30.4          33              8.6
# 3   2025-01-01     Dubai           34.0          37             18.7
# 4   2025-01-01      Doha           28.3          32              6.8
# ..         ...       ...            ...         ...              ...
# 95  2025-01-07     Cairo           32.1          34             35.5
# 96  2025-01-07    London            9.8          94             27.9
# 97  2025-01-07  New York           40.3          48             11.7
# 98  2025-01-07     Tokyo           40.1          74             30.8
# 99  2025-01-07     Paris           42.7          38             16.1
#
#     Precipitation_mm      Condition
# 0               0.00         Cloudy
# 1               3.71          Windy
# ...

# %% [markdown]
# **Skip bad lines**

# %%
pd.read_csv('netflix_movies (1).csv',sep=';',encoding='latin-1',on_bad_lines='skip')
# Out:
#      show_id,type,title,director,cast,country,date_added,release_year,rating,duration,listed_in,description
# 0     s1,Movie,Dick Johnson Is Dead,Kirsten Johnson,...
# 1     s2,TV Show,Blood & Water,,"Ama Qamata, Khosi N...
# 2     s3,TV Show,Ganglands,Julien Leclercq,"Sami Bou...
# 3     s4,TV Show,Jailbirds New Orleans,,,,"September...
# 4     s5,TV Show,Kota Factory,,"Mayur More, Jitendra...
# ...                                                 ...
# 8798  s8803,Movie,Zodiac,David Fincher,"Mark Ruffalo...
# 8799  s8804,TV Show,Zombie Dumb,,,,"July 1, 2019",20...
# 8800  s8805,Movie,Zombieland,Ruben Fleischer,"Jesse ...
# 8801  s8806,Movie,Zoom,Peter Hewitt,"Tim Allen, Cour...
# 8802  s8807,Movie,Zubaan,Mozez Singh,"Vicky Kaushal,...
#
# [8803 rows x 1 columns]

# %% [markdown]
# **dtypes parameter**

# %%
pd.read_csv('netflix_movies (1).csv',dtype={'release_year':int})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# **Handling Dates**

# %%
pd.read_csv('netflix_movies (1).csv',parse_dates=['release_year']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   datetime64[ns]
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 825.8+ KB

# %%
def rename(name):
    if name =="Kota Factory":
        return "KF"
    else:
        return name

# %%
rename("Kota Factory")
# Out:
# 'KF'

# %% [markdown]
# **Convertors**

# %%
pd.read_csv('netflix_movies (1).csv',converters={'title':rename})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show                     KF              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# **na_values parameters**

# %%
pd.read_csv('weather_dataset_2025.csv',na_values=['Mumbai'])
# Out:
#             Date       City  Temperature_C  Humidity_%  Wind_Speed_km_h  \
# 0     2025-01-01     Riyadh           15.8          94             21.0
# 1     2025-01-01     Jeddah           31.5          54             25.3
# 2     2025-01-01     Dammam           30.4          33              8.6
# 3     2025-01-01      Dubai           34.0          37             18.7
# 4     2025-01-01       Doha           28.3          32              6.8
# ...          ...        ...            ...         ...              ...
# 5470  2025-12-31     Sydney           33.5          71             22.9
# 5471  2025-12-31    Toronto            9.1          43             37.4
# 5472  2025-12-31     Berlin            6.3          42             23.7
# 5473  2025-12-31        NaN           27.6          58             12.5
# 5474  2025-12-31  Singapore           44.3          75              4.6
#
#       Precipitation_mm      Condition
# 0                 0.00         Cloudy
# ...

# %% [markdown]
# **Loading a huge datasets in chucks**

# %%
dfs=pd.read_csv("weather_dataset_2025.csv",chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (475, 7)
