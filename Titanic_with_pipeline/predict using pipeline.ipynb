# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
#Assume user input 
test_input=np.array([2,'male',31,4,5,0,'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# C:\Users\Yatha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\Yatha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
